# %%
from ingest import load_faq_data, build_index
from dotenv import load_dotenv
from openai import OpenAI
import os

# %%
load_dotenv()

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
from minsearch import Index

index = Index(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"]
)

index.fit(documents)

# %%
documents=load_faq_data()

# %%
from rag_helper import RAGBase

# %%
assistant = RAGBase( index,openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 assistant.rag('I just discovered the course, can I still join?')
#
# File /app/rag_helper.py:80, in rag(self, query)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /app/rag_helper.py:70, in llm(self, prompt)
#      65     context = self.build_context(search_results)
#      66     return self.prompt_template.format(
#      67         question=query, context=context
#      68     )
# ---> 70 def llm(self, prompt):
#      71     input_messages = [
#      72         {'role': 'developer', 'content': self.instructions},
#      73         {'role': 'user', 'content': prompt}
#      74     ]
#      76     response = self.llm_client.responses.create(
#      77         model=self.model,
#      78         input=input_messages
#      79     )
#
# File /usr/local/lib/python3.13/site-packages/openai/resources/responses/responses.py:944, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     905 def create(
#     906     self,
#     907     *,
#    (...)    942     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     943 ) -> Response | Stream[ResponseStreamEvent]:
# --> 944     return self._post(
#     945         "/responses",
#     946         body=maybe_transform(
#     947             {
#     948                 "background": background,
#     949                 "context_management": context_management,
#     950                 "conversation": conversation,
#     951                 "include": include,
#     952                 "input": input,
#     953                 "instructions": instructions,
#     954                 "max_output_tokens": max_output_tokens,
#     955                 "max_tool_calls": max_tool_calls,
#     956                 "metadata": metadata,
#     957                 "model": model,
#     958                 "parallel_tool_calls": parallel_tool_calls,
#     959                 "previous_response_id": previous_response_id,
#     960                 "prompt": prompt,
#     961                 "prompt_cache_key": prompt_cache_key,
#     962                 "prompt_cache_retention": prompt_cache_retention,
#     963                 "reasoning": reasoning,
#     964                 "safety_identifier": safety_identifier,
#     965                 "service_tier": service_tier,
#     966                 "store": store,
#     967                 "stream": stream,
#     968                 "stream_options": stream_options,
#     969                 "temperature": temperature,
#     970                 "text": text,
#     971                 "tool_choice": tool_choice,
#     972                 "tools": tools,
#     973                 "top_logprobs": top_logprobs,
#     974                 "top_p": top_p,
#     975                 "truncation": truncation,
#     976                 "user": user,
#     977             },
#     978             response_create_params.ResponseCreateParamsStreaming
#     979             if stream
#     980             else response_create_params.ResponseCreateParamsNonStreaming,
#     981         ),
#     982         options=make_request_options(
#     983             extra_headers=extra_headers,
#     984             extra_query=extra_query,
#     985             extra_body=extra_body,
#     986             timeout=timeout,
#     987             security={"bearer_auth": True},
#     988         ),
#     989         cast_to=Response,
#     990         stream=stream or False,
#     991         stream_cls=Stream[ResponseStreamEvent],
#     992     )
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-5.4-mini` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'code': 'model_not_found'}}
