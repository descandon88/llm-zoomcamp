# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

files = reader.read()

# %%
documents = []

for file in files:
    doc = file.parse()
    documents.append(doc)

# %%
len(documents)
# Out:
# 72

# %% [markdown]
# ## QUERTION 2
#
# ### Q2. Indexing and searching
# ### Index the documents with minsearch - make content a text field and filename a keyword field. Then search with this query:
#
# ### How does the agentic loop keep calling the model until it stops?

# %%
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
def llm(prompt):
    response = openai_client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
question = "How does the agentic loop keep calling the model until it stops?"
answer = llm(question)
print(answer)
# Out:
# The Agentic Loop is a concept developed by Facebook Research, and it is used to control the sampling process in large language models, such as those based on the transformer architecture. The agentic loop can be complex, but I'll try to provide a simplified overview of how it works.
#
# **Agentic Loop Overview**
#
# The agentic loop is a iterative process that involves the following stages:
#
# 1. **Initialization**: The model is initialized with a specific prompt, context, or starting state.
# 2. **Sample Generation**: The model takes the current state as input and generates one or more samples (e.g., text, images, etc.).
# 3. **Evaluation**: The generated samples are evaluated against a set of goals, constraints, or objectives (e.g., coherence, relevance, etc.).
# 4. **Feedback**: The evaluation process generates feedback, which is used to guide the next iteration of the model.
# 5. **Loop Repeat**: Steps 2-4 are repeated until a stopping criterion is met (e.g., maximum number of iterations, timeout, convergence, or success).
#
# **Key Mechanisms**
#
# Two key mechanisms enable the agentic loop to keep calling the model until it stops:
#
# 1. **Backpropagation**: During the evaluation step, the model's output is compared to the desired output or goal. The difference between these two is computed, and backpropagation is used to update the model's parameters.
# 2. **Entropy-based control**: The feedback from the evaluation process is used to compute an entropy measure, which controls the temperature of the distribution over possible next actions (e.g., words, actions, etc.). The entropy measure helps the model decide which action to take next. If the entropy is low, the model is more deterministic, and if it's high, the model is more exploratory.
#
# **Stopping Criteria**
#
# The agentic loop has several stopping criteria, which depend on the application domain and the specific model:
#
# 1. **Maximum Iterations**: The loop stops after a fixed number of iterations.
# 2. **Timeout**: The loop stops after a certain amount of time.
# 3. **Convergence**: The model's output converges to a specific goal or value.
# 4. **Success**: The model achieves a specific objective or goal.
# 5. **Manual Termination**: A user or developer decides to terminate the loop manually.
#
# By continuously iterating between sample generation, evaluation, and feedback, the agentic loop adapts the model's parameters to achieve a specific goal or objective. The entropy-based control mechanism helps the model navigate the tradeoff between exploration and exploitation, ensuring that the agentic loop converges or achieves the desired outcome in a reasonable number of iterations.

# %%
from minsearch import Index

index = Index(
    text_fields=["content"],
    keyword_fields=["filename"]
)

index.fit(documents)

# %%
results = index.search("How does the agentic loop keep calling the model until it stops?")
print(results[0]["filename"])
# Out:
# 01-agentic-rag/lessons/14-agentic-loop.md

# %%
#question = "I just discovered the course. Can I join now?"

search_results = index.search(
    question,
    boost_dict={"question": 2.0, "section": 0.5},
    filter_dict={"course": "llm-zoomcamp"},
    num_results=1
)

search_results
# Out:
# ['filename']

# %%
def search(question, course="llm-zoomcamp"):
    return index.search(
        question,
     #   filter_dict={"course": "llm-zoomcamp"},
        num_results=1
    )

# %%
search_results = search(question)
print(search_results[0]["filename"])
# Out:
# 01-agentic-rag/lessons/14-agentic-loop.md

# %% [markdown]
# ## Q3. RAG
# ### Now we will build a RAG assistant on top of this data. Let's use the rag helper script we prepared during the lessons:

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Out:
# --2026-06-22 03:21:03--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2134 (2.1K) [text/plain]
# Saving to: ‘rag_helper.py’
#
# rag_helper.py       100%[===================>]   2.08K  --.-KB/s    in 0.002s
#
# 2026-06-22 03:21:03 (968 KB/s) - ‘rag_helper.py’ saved [2134/2134]

# %% [markdown]
# ### Two solutions are possible:
#
# #### Implement the RAG flow yourself
# #### Take RAGBase and change the parts related to the FAQ schema - search (to use our index) and build_context
# #### Build a RAG over the index from Q2 and answer the query:
#
# ### How does the agentic loop keep calling the model until it stops?

# %%
from rag_helper import RAGBase
import importlib
import rag_helper
importlib.reload(rag_helper)
#from rag_helper import RAGBase
# Out:
# <module 'rag_helper' from '/app/01-homework/rag_helper.py'>

# %%
assistant = RAGBase( index,openai_client)

# %%
assistant.rag('How does the agentic loop keep calling the model until it stops?')
# Out:
# "I'm ready to answer your questions based on the provided context. What would you like to know?"

# %%
answer = assistant.rag('How does the agentic loop keep calling the model until it stops?')

assistant.last_usage

assistant.last_usage.prompt_tokens
assistant.last_usage.completion_tokens
assistant.last_usage.total_tokens
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 3
#       1 answer = assistant.rag('How does the agentic loop keep calling the model until it stops?')
#       2
# ----> 3 assistant.last_usage
#       4 # CompletionUsage(prompt_tokens=..., completion_tokens=..., total_tokens=...)
#       5
#       6 assistant.last_usage.prompt_tokens
#
# AttributeError: 'RAGBase' object has no attribute 'last_usage'
