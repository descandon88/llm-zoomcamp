# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

files = reader.read()

# %%
documents = []

for file in files:
    doc = file.parse()
    documents.append(doc)

# %%
len(documents)
# Out:
# 72

# %% [markdown]
# ## QUERTION 2
#
# ### Q2. Indexing and searching
# ### Index the documents with minsearch - make content a text field and filename a keyword field. Then search with this query:
#
# ### How does the agentic loop keep calling the model until it stops?

# %%
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
def llm(prompt):
    response = openai_client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
question = "How does the agentic loop keep calling the model until it stops?"
answer = llm(question)
print(answer)
# Out:
# The agentic loop, as used in the Llama model, refers to a self-supervised learning mechanism. The process is as follows:
#
# 1. **Text Input**: The agentic loop starts with a given input text, which could be a question or a topic.
#
# 2. **Text Generation**: The Llama model generates a response based on the input text using its large language model. This response is essentially a continuation of the input text.
#
# 3. **Self-Criticism**: The Llama model then evaluates or criticizes its own generated response based on a set of pre-defined metrics (e.g., fluency, coherence). This evaluation is an internal process and does not involve human oversight.
#
# 4. **Self-Updating**: If the model determines that its generated response is inadequate or requires improvement, it can use this self-criticism to adjust and refine its internal knowledge representation. This can lead to the generation of a better response, which then becomes the new text input for the next iteration of the agentic loop.
#
# 5. **Convergence**: The agentic loop keeps calling the model until the model determines that its generated response is suitable. This process is self-regulated and may require thousands of iterations before it converges on a final answer or output. When no further improvements are made, the agentic loop stops, and the final response is output.

# %%
from minsearch import Index

index = Index(
    text_fields=["content"],
    keyword_fields=["filename"]
)

index.fit(documents)

# %%
results = index.search("How does the agentic loop keep calling the model until it stops?")
print(results[0]["filename"])
# Out:
# 01-agentic-rag/lessons/14-agentic-loop.md

# %%
#question = "I just discovered the course. Can I join now?"

# %%
def search(question, course="llm-zoomcamp"):
    return index.search(
        question,
     #   filter_dict={"course": "llm-zoomcamp"},
        num_results=1
    )

# %%
search_results = search(question)
print(search_results[0]["filename"])
# Out:
# 01-agentic-rag/lessons/14-agentic-loop.md

# %% [markdown]
# ## Q3. RAG
# ### Now we will build a RAG assistant on top of this data. Let's use the rag helper script we prepared during the lessons:

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Out:
# --2026-06-23 03:43:33--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2134 (2.1K) [text/plain]
# Saving to: ‘rag_helper.py.2’
#
# rag_helper.py.2     100%[===================>]   2.08K  --.-KB/s    in 0.003s
#
# 2026-06-23 03:43:33 (785 KB/s) - ‘rag_helper.py.2’ saved [2134/2134]

# %% [markdown]
# ### Two solutions are possible:
#
# #### Implement the RAG flow yourself
# #### Take RAGBase and change the parts related to the FAQ schema - search (to use our index) and build_context
# #### Build a RAG over the index from Q2 and answer the query:
#
# ### How does the agentic loop keep calling the model until it stops?

# %%
from rag_helper import RAGBase
import importlib
import rag_helper
importlib.reload(rag_helper)
#from rag_helper import RAGBase
# Out:
# <module 'rag_helper' from '/app/01-homework/rag_helper.py'>

# %%
assistant = RAGBase( index,openai_client)

# %%
assistant.rag('How does the agentic loop keep calling the model until it stops?')
# Out:
# "I'm ready to answer your questions based on the provided context about the Agentic Loop. Go ahead and ask your question."

# %%
answer = assistant.rag('How does the agentic loop keep calling the model until it stops?')

assistant.last_usage
# Out:
# CompletionUsage(completion_tokens=381, prompt_tokens=7221, total_tokens=7602, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.156757238, prompt_time=0.60917585, completion_time=1.603622028, total_time=2.212797878)

# %%
assistant.last_usage.prompt_tokens
# Out:
# 7221

# %%
assistant.last_usage.completion_tokens
# Out:
# 381

# %%
assistant.last_usage.total_tokens
# Out:
# 7602

# %%
# Q4. Chunking

# %%
from gitsource import chunk_documents

chunks = chunk_documents(documents, size=2000, step=1000)

# %%
len(chunks[0])
# Out:
# 3

# %%
# Build a new index on the chunks
chunk_index = Index(
    text_fields=["content"],
    keyword_fields=["filename"]
)
chunk_index.fit(chunks)

# Search with the same query
results = chunk_index.search(
    "How does the agentic loop keep calling the model until it stops?"
)

print(results[0]["filename"])
print(results[0]["start"])   # offset where this chunk begins in the original page
# Out:
# 01-agentic-rag/lessons/14-agentic-loop.md
# 4000

# %% [markdown]
# # Q4. Chunking

# %%
assistant_chunk = RAGBase( chunk_index,openai_client)
assistant_chunk
assistant_chunk.rag('How does the agentic loop keep calling the model until it stops?')
# Out:
# "The agentic loop keeps calling the model until it stops by using a `while True` loop that continues to execute until a certain condition is met. The condition is that the model returns a response without any function calls. \n\nIn the code, this is implemented by a `has_function_calls` flag that is initially set to `False`. If the model's response contains any function calls, the flag is set to `True`. After processing the model's response, the loop checks the flag. If it's still `False`, the loop breaks, indicating that the model has returned a final answer with no more tool calls. \n\nHere's the relevant part of the code:\n```python\nwhile True:\n    ...\n    has_function_calls = False\n    ...\n    if has_function_calls == False:\n        break\n```\nThis ensures that the loop keeps calling the model until it returns a response without any function calls, at which point the loop stops."

# %%
assistant_chunk.last_usage
# Out:
# CompletionUsage(completion_tokens=192, prompt_tokens=2348, total_tokens=2540, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.241298721, prompt_time=0.122246635, completion_time=0.62627225, total_time=0.748518885)

# %%
assistant_chunk.last_usage.total_tokens
# Out:
# 2540

# %%
assistant.last_usage.total_tokens/assistant_chunk.last_usage.total_tokens
# Out:
# 2.9929133858267716

# %% [markdown]
# # Q5.

# %%
def search_chunk(question, course="llm-zoomcamp"):
    return chunk_index.search(
        question,
     #   filter_dict={"course": "llm-zoomcamp"},
        num_results=1
    )

# %%
search = search_chunk('How does the agentic loop work, and how is it different from plain RAG?')

# %%
search
# Out:
# [{'start': 4000,
#   'content': 'esult.\n\nThe `result` is a `LoopResult` with `all_messages` (the full\nconversation), token counts, and `cost` (computed from token usage).\n\n## Cost and tokens\n\nLook at what the call cost:\n\n```python\nresult.cost\n```\n\nUseful while developing - especially with multi-turn agents where one\nprompt can trigger several model calls. The handwritten loop made you\ncompute this by hand. The framework keeps a running total for you.\n\nYou can also look at the full message history.\n\n```python\nresult.all_messages\n```\n\nThis is just a list - the same `messages` list we maintained by hand.\n\n## Continuing the conversation\n\nTake the messages from the previous result and pass them as\n`previous_messages` on the next `loop` call:\n\n```python\nresult2 = runner.loop(\n    prompt="How do I run a different model?",\n    previous_messages=result.all_messages,\n    callback=callback,\n)\n```\n\nThe runner picks up where the last call left off, with the same agent\nloop and an extended history. The model knows "different model" refers\nto Ollama because it sees the previous turn in memory. Without that\nhistory, it would have no idea what we\'re asking about.\n\n## Interactive chat\n\nFor a chat-like workflow, run the built-in input loop:\n\n```python\nrunner.run()\n```\n\nType questions and get answers. Type "stop" to exit.\n\n[← The Agentic Loop](14-agentic-loop.md) | [Other Frameworks →](16-other-frameworks.md)',
#   'filename': '01-agentic-rag/lessons/15-frameworks.md'}]
