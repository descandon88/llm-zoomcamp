# %%
import pandas as pd

df_ground_truth = pd.read_csv("data/ground_truth-new.csv")
ground_truth = df_ground_truth.to_dict(orient="records")

# %%
import sys
sys.path.insert(0, '/app/04-evaluation/code')

# %%
from ingest import load_faq_data, build_index

documents = load_faq_data()

documents_llm = []

for doc in documents:
    if doc["course"] == "llm-zoomcamp":
        documents_llm.append(doc)

documents = documents_llm
index = build_index(documents)

# %%
for q in ground_truth:
    #q = ground_truth[g]
    print(q)
# Out:
# {'question': 'Is it okay to join the course late if I just found it now?', 'document': '74eb249bbf'}
# {'question': 'Can I still take this course even if I missed the start date?', 'document': '74eb249bbf'}
# {'question': 'If I join after the course has already started, am I still eligible for a certificate?', 'document': '74eb249bbf'}
# {'question': 'Do I need to submit my project before submissions close to get the certificate?', 'document': '74eb249bbf'}
# {'question': 'I’m a bit late to the course—what do I need to do to still earn the certificate?', 'document': '74eb249bbf'}
# {'question': 'I registered for the LLM Zoomcamp — when should I expect a confirmation email?', 'document': '977bf7786c'}
# {'question': 'Do I actually need an acceptance email before I can start the course and hand in homework?', 'document': '977bf7786c'}
# {'question': 'If I filled out the registration form, does that mean I’m officially on a checked list for the course?', 'document': '977bf7786c'}
# {'question': 'Is registering for the LLM Zoomcamp required, or is it just for estimating interest before the course starts?', 'document': '977bf7786c'}
# {'question': 'Can I begin learning and submit homework even if I never got any email after signing up?', 'document': '977bf7786c'}
# {'question': 'How do I join the Office Hours or live workshop if I don’t have the Zoom link?', 'document': '489dd1c9d9'}
# {'question': 'Where can I watch the live sessions for the course, and how do I ask questions during them?', 'document': '489dd1c9d9'}
# {'question': 'Is the Zoom link for the workshop shared with students, or only with the teaching team?', 'document': '489dd1c9d9'}
# {'question': 'What’s the best way to follow the live Office Hours stream if I’m a student?', 'document': '489dd1c9d9'}
# {'question': 'Should I type my questions in the live chat during Office Hours, or use something else?', 'document': '489dd1c9d9'}
# {'question': 'How do the free GPU hours work on these cloud options — is the limit monthly, weekly, or something else?', 'document': 'c6c2888275'}
# {'question': 'If I change the setup or configuration, does that affect the free GPU quota or get billed separately?', 'document': 'c6c2888275'}
# {'question': 'What are some good free or low-cost cloud alternatives with GPU for this course besides the usual ones?', 'document': 'c6c2888275'}
# {'question': 'Can I use Google Colab, Kaggle, or Databricks for the course notebooks and GPU tasks?', 'document': 'c6c2888275'}
# {'question': 'Are there any restrictions on what I can install on these free GPU platforms, and how do I check what’s included in the free plan?', 'document': 'c6c2888275'}
# {'question': 'How do I find my row on the leaderboard if I can’t see my name right away?', 'document': 'c2903069a0'}
# {'question': 'Why does the leaderboard show some random nickname instead of my real name?', 'document': 'c2903069a0'}
# {'question': 'Where can I check what display name I’m using for the course?', 'document': 'c2903069a0'}
# {'question': 'Can I change the name that appears publicly, like to my Slack or GitHub name?', 'document': 'c2903069a0'}
# {'question': 'What should I put in the profile fields so my certificate doesn’t use the default random name?', 'document': 'c2903069a0'}
# {'question': 'Can I do the course at my own pace and still get a certificate at the end?', 'document': '69d122f12e'}
# {'question': 'If I take the self-paced version, is there any way to earn the course certificate?', 'document': '69d122f12e'}
# {'question': 'Do certificates only count for people who finish with the live cohort?', 'document': '69d122f12e'}
# {'question': 'Why doesn’t the self-paced mode come with a certificate?', 'document': '69d122f12e'}
# {'question': 'Is peer-review of the capstone project required in order to receive the certificate?', 'document': '69d122f12e'}
# {'question': 'Can I still get the certificate if I skipped the first homework?', 'document': '9f689c185f'}
# {'question': 'Do I have to do all the homework to receive the certificate for this course?', 'document': '9f689c185f'}
# {'question': 'What do I actually need to pass in order to get the certificate?', 'document': '9f689c185f'}
# {'question': 'Is homework mandatory, or is it just optional practice for the course?', 'document': '9f689c185f'}
# {'question': "If homework isn't required, does it still affect anything like my ranking or points?", 'document': '9f689c185f'}
# {'question': 'Why does the homework content keep changing in this course?', 'document': '96286b4be4'}
# {'question': 'Is the material already finalized, or can it still change later?', 'document': '96286b4be4'}
# {'question': 'If I start working on the homework now, could the final version be different?', 'document': '96286b4be4'}
# {'question': 'How will I know when a module is actually ready and settled?', 'document': '96286b4be4'}
# {'question': 'Is it safe to do the course work in advance, or should I wait until updates are announced?', 'document': '96286b4be4'}
# {'question': 'When is the next time this course will be offered?', 'document': 'bd31146b0e'}
# {'question': 'Do you know when the next course session starts?', 'document': 'bd31146b0e'}
# {'question': 'Will there be another run of this course, and if so, when?', 'document': 'bd31146b0e'}
# {'question': "What's the next scheduled offering for this course?", 'document': 'bd31146b0e'}
# {'question': 'Can you tell me when the course is coming back?', 'document': 'bd31146b0e'}
# {'question': 'Where can I find the course lectures or videos for this class?', 'document': '31456f4b5f'}
# {'question': 'Are the recordings or lecture videos posted somewhere I can watch them?', 'document': '31456f4b5f'}
# {'question': 'I’m looking for the videos—should I check the bookmarks or pinned links?', 'document': '31456f4b5f'}
# {'question': 'Is there a specific YouTube channel for the course lectures?', 'document': '31456f4b5f'}
# {'question': 'Where are the lecture videos linked, and what should I check first?', 'document': '31456f4b5f'}
# {'question': 'Why does WSL2 say the model needs more memory even though my PC has enough RAM?', 'document': 'f3dd94f323'}
# {'question': 'How can I increase the RAM available to WSL2 on Windows for running a model?', 'document': 'f3dd94f323'}
# {'question': 'Where should I put a .wslconfig file to give WSL2 more memory?', 'document': 'f3dd94f323'}
# {'question': 'What do I need to write in .wslconfig to set WSL2 memory to 8GB?', 'document': 'f3dd94f323'}
# {'question': 'After changing WSL2 memory settings, how can I check if the new RAM limit is actually applied?', 'document': 'f3dd94f323'}
# {'question': 'Why do I get a 500 server error when I try to log into the homework site with GitHub?', 'document': 'c774542f32'}
# {'question': 'I see a third-party login failure on the course page — is GitHub login broken right now?', 'document': 'c774542f32'}
# {'question': 'What should I do if GitHub sign-in fails while submitting homework?', 'document': 'c774542f32'}
# {'question': 'Is there a workaround for the GitHub login error on the homework portal?', 'document': 'c774542f32'}
# {'question': 'Does the GitHub login issue affect everyone, or can I use another account to submit?', 'document': 'c774542f32'}
# {'question': "Why aren't we using LangChain in this course, and what should we learn first instead?", 'document': 'b7cdde6b25'}
# {'question': 'Is there a reason the course skips LangChain for now?', 'document': 'b7cdde6b25'}
# {'question': 'Why start without a framework like LangChain when building LLM apps?', 'document': 'b7cdde6b25'}
# {'question': 'Should I learn the basics before using LangChain, and why?', 'document': 'b7cdde6b25'}
# {'question': 'What’s the idea behind not using LangChain in the course material?', 'document': 'b7cdde6b25'}
# {'question': 'Why do I get an OpenAI API error about insufficient credits when I run `chat.completions.create`?', 'document': 'f5df151c59'}
# {'question': 'What does the OpenAI "Insufficient credits" message mean in `chat.completions.create`?', 'document': 'f5df151c59'}
# {'question': 'I’m seeing an OpenAI API error about credits when testing chat completions — what should I check?', 'document': 'f5df151c59'}
# {'question': 'Is the `OpenAI API Error: Insufficient credits` issue caused by my `chat.completions.create` call?', 'document': 'f5df151c59'}
# {'question': 'What’s the reason for the credit-related error when using OpenAI chat completions?', 'document': 'f5df151c59'}
# {'question': 'Why am I getting a 429 RateLimitError from OpenAI even though my code looks fine?', 'document': '152af39a53'}
# {'question': 'Does OpenAI API have any free quota for this kind of request, or do I need to pay first?', 'document': '152af39a53'}
# {'question': 'I added billing but still get an insufficient_quota error — do I need to make a new API key?', 'document': '152af39a53'}
# {'question': 'Which model should I use in chat.completions.create if my current one is not available to my account?', 'document': '152af39a53'}
# {'question': 'What are the exact steps to fix the OpenAI quota error and get my request working again?', 'document': '152af39a53'}
# {'question': "Why am I getting 'Cannot import name OpenAI from openai' when I try to use the OpenAI client?", 'document': '35e1ef85a1'}
# {'question': 'How do I fix the OpenAI import error in the course project?', 'document': '35e1ef85a1'}
# {'question': "Do I need to upgrade the openai package if OpenAI can't be imported from openai?", 'document': '35e1ef85a1'}
# {'question': "What version of openai should I use to avoid the 'Cannot import name OpenAI' error?", 'document': '35e1ef85a1'}
# {'question': "My code breaks with 'Cannot import name OpenAI from openai' — what should I change?", 'document': '35e1ef85a1'}
# {'question': 'How much do I need to spend to start using the OpenAI API?', 'document': '554d0eb78b'}
# {'question': 'Is it expensive to use the OpenAI API for this course?', 'document': '554d0eb78b'}
# {'question': 'Do I have to put in a lot of money before I can try the OpenAI API?', 'document': '554d0eb78b'}
# {'question': 'What is the minimum top-up amount for the OpenAI API?', 'document': '554d0eb78b'}
# {'question': 'Can I get started with OpenAI API usage for just a few cents?', 'document': '554d0eb78b'}
# {'question': 'Do I need to pay for the OpenAI API to finish the homework in this course, or are there free options I can use instead?', 'document': '85384a18e5'}
# {'question': 'For the LLM Zoomcamp assignments, is a paid OpenAI subscription required, or can I rely on the free alternatives from the course repo?', 'document': '85384a18e5'}
# {'question': 'Can I complete the course tasks without buying OpenAI API access, and where are the no-cost alternatives listed?', 'document': '85384a18e5'}
# {'question': 'Is paying for OpenAI necessary for the homeworks, or does the GitHub have some free API alternatives I can use?', 'document': '85384a18e5'}
# {'question': 'To do the course exercises, do I have to subscribe to OpenAI, or is there a list of free replacements somewhere in the course materials?', 'document': '85384a18e5'}
# {'question': 'How can I keep my API keys safe in a project without putting them in the notebook or code?', 'document': '8d23fe792f'}
# {'question': "What's a simple way to save several API keys locally so I can load them later in Python?", 'document': '8d23fe792f'}
# {'question': "How do I set up a YAML file for my OpenAI and Groq keys and make sure Git doesn't track it?", 'document': '8d23fe792f'}
# {'question': 'Which package do I need if I want to read API keys from a YAML file in a Jupyter notebook?', 'document': '8d23fe792f'}
# {'question': 'Can I load my secret keys from a file and use them directly instead of using environment variables?', 'document': '8d23fe792f'}
# {'question': 'How do I keep my API key in a .env file and read it in Python?', 'document': '233dabe430'}
# {'question': 'What imports do I need to load environment variables from a .env file?', 'document': '233dabe430'}
# {'question': 'How can I point Python to the right .env path and get the key value?', 'document': '233dabe430'}
# {'question': "What's the easiest way to access API_KEY_abc after loading .env?", 'document': '233dabe430'}
# {'question': 'Do I need to add my .env file to .gitignore, and why?', 'document': '233dabe430'}
# {'question': 'Why does my OPENAI_API_KEY keep showing as missing inside Jupyter, and how do I fix it?', 'document': '86d99bbf21'}
# {'question': 'If I already put the key in a .envrc file, why is the notebook still throwing the api_key error?', 'document': '86d99bbf21'}
# {'question': 'What’s the easiest way to make OpenAI API auth work in a notebook when direnv isn’t enough?', 'document': '86d99bbf21'}
# {'question': 'How do I use python-dotenv to load my environment variables from .envrc in Jupyter?', 'document': '86d99bbf21'}
# {'question': 'Can I store OPENAI_API_KEY in GitHub Codespaces instead of setting it locally, and how do I do that?', 'document': '86d99bbf21'}
# {'question': 'How can I figure out the GPT-4o token count for homework 6 if I’m using Groq and there’s no tokenizer for it?', 'document': 'fe8fed31e6'}
# {'question': 'Do I need an OpenAI API key just to check how many tokens a prompt has in this assignment?', 'document': 'fe8fed31e6'}
# {'question': 'What library should I use to estimate the number of OpenAI tokens in question 6?', 'document': 'fe8fed31e6'}
# {'question': 'Is there a way to count GPT-4o tokens without using the OpenAI API itself?', 'document': 'fe8fed31e6'}
# {'question': 'If Groq doesn’t have a tokenizer, what’s the simplest way to get the token number the homework wants?', 'document': 'fe8fed31e6'}
# {'question': 'Can I swap OpenAI for Groq in the course exercises and final project?', 'document': 'ee43413718'}
# {'question': 'Is it okay to use a different LLM platform instead of OpenAI for the homework?', 'document': 'ee43413718'}
# {'question': 'Do I need a paid API like OpenAI to finish the assignments, or can I run everything locally?', 'document': 'ee43413718'}
# {'question': 'If I use another model provider, will I have to change the code myself?', 'document': 'ee43413718'}
# {'question': 'Where should I look if I want to adapt the project to a platform like Groq?', 'document': 'ee43413718'}
# {'question': 'Can I use open-source alternatives instead of the OpenAI API for this course?', 'document': '3fd5c51182'}
# {'question': 'Where can I find the list of OpenAI alternatives mentioned in Module 1?', 'document': '3fd5c51182'}
# {'question': 'Is it okay to follow the course using an open-source LLM API rather than OpenAI?', 'document': '3fd5c51182'}
# {'question': 'Does the course support non-OpenAI options, and where is that covered?', 'document': '3fd5c51182'}
# {'question': 'What should I check if I want to use an open-source replacement for OpenAI in the intro module?', 'document': '3fd5c51182'}
# {'question': 'Why am I getting RateLimitError 429 with insufficient_quota on OpenAI even though I’m not sending many requests?', 'document': '6e1d8a7b29'}
# {'question': 'Does insufficient_quota mean I just need to wait and retry later, or is something wrong with my account?', 'document': '6e1d8a7b29'}
# {'question': 'My OpenAI API calls fail because of no credit — what’s the quickest fix to get the course working again?', 'document': '6e1d8a7b29'}
# {'question': 'Can I use a free alternative instead of paying for OpenAI credit, and which ones work with the course?', 'document': '6e1d8a7b29'}
# {'question': 'What model or provider should I switch to if I want to avoid the quota error without adding money to OpenAI?', 'document': '6e1d8a7b29'}
# {'question': 'Why does my homework query return an empty list after filtering, even though the data is there?', 'document': '83da208a64'}
# {'question': 'What am I missing if my Q3 filter gives no results in the LLM Zoomcamp homework?', 'document': '83da208a64'}
# {'question': 'Could this be an indexing problem if the search comes back empty after I apply the filter?', 'document': '83da208a64'}
# {'question': 'Do I need to set up the index differently before loading the data for this assignment?', 'document': '83da208a64'}
# {'question': 'How should I fix the empty results issue in HW Q3 when using filters and queries?', 'document': '83da208a64'}
# {'question': 'Why am I getting a SyntaxError about an invalid character when I run the minsearch file I downloaded?', 'document': 'f3a92e7c81'}
# {'question': 'Did I probably save the GitHub page instead of the actual Python source for minsearch?', 'document': 'f3a92e7c81'}
# {'question': 'What’s the right way to download minsearch from GitHub so I can run it without that weird character error?', 'document': 'f3a92e7c81'}
# {'question': 'Is there a better way to install minsearch than copying the file from GitHub by hand?', 'document': 'f3a92e7c81'}
# {'question': 'Should I use pip or uv to install minsearch instead of downloading the raw code?', 'document': 'f3a92e7c81'}
# {'question': 'Why do I get ModuleNotFoundError when I try to import docx in parse-faq.ipynb?', 'document': 'cf93377279'}
# {'question': 'Is the package name for docx actually python-docx?', 'document': 'cf93377279'}
# {'question': 'What should I install if import docx keeps failing in the notebook?', 'document': 'cf93377279'}
# {'question': 'How do I fix the docx import issue in parse-faq.ipynb?', 'document': 'cf93377279'}
# {'question': 'Do I need to pip install python-docx instead of docx?', 'document': 'cf93377279'}
# {'question': 'How can I check token usage for Gemini, Mistral, or Hugging Face models if tiktoken is really meant for OpenAI only?', 'document': '4d8c1f5b3a'}
# {'question': 'Is it okay to use cl100k_base as a fallback tokenizer for other LLM providers when I want an estimate?', 'document': '4d8c1f5b3a'}
# {'question': 'What is the recommended way to count tokens in Gemini with the official SDK?', 'document': '4d8c1f5b3a'}
# {'question': 'How do I get token counts for open-source models like Llama using Transformers?', 'document': '4d8c1f5b3a'}
# {'question': 'Which tokenizer should I use for Mistral instead of trying to rely on OpenAI-style token counting?', 'document': '4d8c1f5b3a'}
# {'question': 'Why do I get a different token count in tiktoken than what OpenAI shows in the API response?', 'document': 'bf0403d21b'}
# {'question': 'How come my prompt has 320 tokens locally, but OpenAI says 327 for the same request?', 'document': 'bf0403d21b'}
# {'question': 'Does chat.completions.create add extra tokens beyond the text I send?', 'document': 'bf0403d21b'}
# {'question': 'What makes OpenAI count more tokens than just encoding the visible message content?', 'document': 'bf0403d21b'}
# {'question': 'Can whitespace, newlines, or weird Unicode characters change the token total in OpenAI chat requests?', 'document': 'bf0403d21b'}
# {'question': 'How can I set my API key once so I don’t have to export it in every new terminal?', 'document': '8b2f5e9d04'}
# {'question': 'Is there a way to make env vars load automatically when I enter a project folder?', 'document': '8b2f5e9d04'}
# {'question': 'What’s the easiest setup for keeping my OpenAI key in a project without putting it in the code?', 'document': '8b2f5e9d04'}
# {'question': 'How should I handle API keys in GitHub Codespaces so they aren’t stored in the repo?', 'document': '8b2f5e9d04'}
# {'question': 'If I’m running Python scripts, what can I use to load a .env file automatically?', 'document': '8b2f5e9d04'}
# {'question': 'How do I install Ollama on macOS, Windows, or Linux for this course?', 'document': '1d0b969028'}
# {'question': 'What should I run after installing Ollama to download and start LLaMA 3 locally?', 'document': '1d0b969028'}
# {'question': 'How can I quickly check if the Ollama server is actually running on my machine?', 'document': '1d0b969028'}
# {'question': 'After installing Ollama, how do I get the Python package and use it from a script?', 'document': '1d0b969028'}
# {'question': 'What’s the simplest example of calling Ollama chat from Python with a prompt?', 'document': '1d0b969028'}
# {'question': 'Why am I getting a connection refused error when I prompt my Ollama RAG, and how do I fix it?', 'document': 'c6fc2d4d11'}
# {'question': 'My homework throws connection refused with Ollama — do I need to restart the server somehow?', 'document': 'c6fc2d4d11'}
# {'question': 'What should I run again if Ollama stops working after I restart the notebook cell?', 'document': 'c6fc2d4d11'}
# {'question': 'Is there a command to bring Ollama back up when the RAG prompt fails with connection refused?', 'document': 'c6fc2d4d11'}
# {'question': 'I closed or restarted the notebook and now Ollama won’t respond; what’s the quickest way to recover it?', 'document': 'c6fc2d4d11'}
# {'question': 'Which free Groq models support tool use right now?', 'document': '0d74a3616f'}
# {'question': 'Can I use Deepseek R1 with tools on Groq without paying?', 'document': '0d74a3616f'}
# {'question': 'Does Llama 4 on Groq work for tool calling in dev?', 'document': '0d74a3616f'}
# {'question': 'Are there any no-cost models I can test with tool use support?', 'document': '0d74a3616f'}
# {'question': 'Where can I read the docs for Groq tool use and free models?', 'document': '0d74a3616f'}
# {'question': 'Why do I get `RuntimeError: Already running asyncio in this thread` in Jupyter when I use `asyncio.run()`?', 'document': '7c4e1a3b58'}
# {'question': 'In a notebook, what should I do instead of `asyncio.run(main())` for an async function?', 'document': '7c4e1a3b58'}
# {'question': 'For the agents homework, should I use `mcp.run()` or `mcp.run_async()` in the notebook?', 'document': '7c4e1a3b58'}
# {'question': 'How do I start the FastMCP server for the homework without hitting the asyncio error?', 'document': '7c4e1a3b58'}
# {'question': 'When the homework says to run the server, do I launch `python weather_server.py` in Jupyter or in a terminal?', 'document': '7c4e1a3b58'}
# {'question': 'Why does my MCP tool complain that it wanted a number even though I sent a float?', 'document': '5beafdd0c8'}
# {'question': 'In FastMCP, is a Python float not considered valid for a numeric tool argument?', 'document': '5beafdd0c8'}
# {'question': 'When I define a tool input schema, should I think in Python types or JSON types?', 'document': '5beafdd0c8'}
# {'question': 'How do I make sure the arguments I send to a tool match its schema correctly?', 'document': '5beafdd0c8'}
# {'question': 'Does the JSON Schema type number include both ints and floats?', 'document': '5beafdd0c8'}
# {'question': 'Which non-OpenAI APIs actually work for tool calling in this module?', 'document': '2a8f6c4d91'}
# {'question': 'Does Groq support function calling, and if yes, which model should I try?', 'document': '2a8f6c4d91'}
# {'question': 'Can I use Mistral or Gemini for tool use here, or are they missing something compared with OpenAI?', 'document': '2a8f6c4d91'}
# {'question': 'Is Ollama okay for local tool calling in the agents homework, and what model/setup does it need?', 'document': '2a8f6c4d91'}
# {'question': 'If I switch away from OpenAI, what parts of chat_assistant.py or mcp_client.py usually need changes?', 'document': '2a8f6c4d91'}
# {'question': 'How do I install the MCP Inspector for this course?', 'document': 'd09e8d4843'}
# {'question': 'What command should I run to get the MCP Inspector installed?', 'document': 'd09e8d4843'}
# {'question': 'Do I need Node.js first before installing the MCP Inspector?', 'document': 'd09e8d4843'}
# {'question': 'What’s the npm install command for the MCP Inspector package?', 'document': 'd09e8d4843'}
# {'question': 'I’m on Module 2 Agents — how can I set up the MCP Inspector?', 'document': 'd09e8d4843'}
# {'question': "Why do I get `AttributeError: 'str' object has no attribute 'output'` when I call OpenAI Responses API with a non-OpenAI model?", 'document': '9e7b3f0c25'}
# {'question': 'Can I use `client.responses.create(...)` and `response.output` with Mistral, Groq, or Gemini in my agent code?', 'document': '9e7b3f0c25'}
# {'question': "What should I use instead of the Responses API if I'm switching my LLM provider away from OpenAI?", 'document': '9e7b3f0c25'}
# {'question': "How do I read the assistant reply from chat completions when the provider doesn't support OpenAI's Responses API?", 'document': '9e7b3f0c25'}
# {'question': 'Do I need to change my tools schema too when I move from OpenAI to another model provider?', 'document': '9e7b3f0c25'}
# {'question': 'How do I start the MCP Inspector from the terminal?', 'document': '42c7af7ed5'}
# {'question': 'What command should I run to open the MCP Inspector?', 'document': '42c7af7ed5'}
# {'question': 'Is there a simple npx command for launching the MCP Inspector?', 'document': '42c7af7ed5'}
# {'question': 'How can I run the Model Context Protocol Inspector locally?', 'document': '42c7af7ed5'}
# {'question': 'What’s the terminal command to inspect MCP with the Inspector tool?', 'document': '42c7af7ed5'}
# {'question': 'How do I connect the inspector to an MCP server in this module?', 'document': '9c2fd5451c'}
# {'question': 'Can the MCP inspector show the tools and other things exposed by a server?', 'document': '9c2fd5451c'}
# {'question': 'What can I check inside an MCP server using the inspector?', 'document': '9c2fd5451c'}
# {'question': 'Is there a way to test my MCP server without writing extra code?', 'document': '9c2fd5451c'}
# {'question': 'Where can I find a quick guide for using MCP Inspector with my server?', 'document': '9c2fd5451c'}
# {'question': 'Why do I get "asyncio.run() cannot be called from a running event loop" in Jupyter, and what should I use instead?', 'document': 'f96fde1726'}
# {'question': 'In a notebook cell, why does calling `asyncio.run(main())` fail even though the same code works in a script?', 'document': 'f96fde1726'}
# {'question': 'What’s the right way to run an async function in Jupyter without hitting the asyncio runtime error?', 'document': 'f96fde1726'}
# {'question': 'How can I fix the "already running asyncio" error when using `Client(weather_server.mcp)` inside a notebook?', 'document': 'f96fde1726'}
# {'question': 'Is there a reason I should use `await main()` instead of `asyncio.run(main())` in Jupyter notebooks?', 'document': 'f96fde1726'}
# {'question': 'Why am I getting a 400 missing required parameter for tools[0].function in Azure OpenAI?', 'document': 'b9c7c6bb34'}
# {'question': 'What should the get_weather_tool JSON look like to fix the tools[0].function error?', 'document': 'b9c7c6bb34'}
# {'question': 'How do I define a weather function tool so Azure OpenAI accepts it?', 'document': 'b9c7c6bb34'}
# {'question': 'My Azure OpenAI request fails with missing tools[0].function — what am I doing wrong?', 'document': 'b9c7c6bb34'}
# {'question': 'Can you show the correct function tool schema for get_weather in Module 2 agents?', 'document': 'b9c7c6bb34'}
# {'question': 'What do embeddings mean in vector search, and why do we convert text into numbers?', 'document': '69430a79a8'}
# {'question': 'How can an embedding keep the meaning of words or documents when turning them into numerical values?', 'document': '69430a79a8'}
# {'question': 'Why do similar inputs end up with close vectors in an embedding model?', 'document': '69430a79a8'}
# {'question': 'How are embeddings used to measure semantic similarity between pieces of text?', 'document': '69430a79a8'}
# {'question': 'What is the connection between embeddings, vector space models, and dimensionality reduction?', 'document': '69430a79a8'}
# {'question': 'How do I get rid of the warning about multi-qa-mpnet-base-dot-v1 and sentence-transformers bet?', 'document': 'aa3f597424'}
# {'question': 'What should I install to suppress the model warning in vector search?', 'document': 'aa3f597424'}
# {'question': 'Is there a fix for the message saying this model was made with sentence-transformers v3?', 'document': 'aa3f597424'}
# {'question': 'Which sentence-transformers version do I need so that the warning stops showing up?', 'document': 'aa3f597424'}
# {'question': 'How can I upgrade my setup to avoid that bet warning from the embedding model?', 'document': 'aa3f597424'}
# {'question': 'Why did the lesson use `.dot(...)` for cosine similarity, but the homework says to normalize first?', 'document': '92cd22cada'}
# {'question': 'Are the embeddings from `model.encode(...)` already unit-length, or do I need to normalize them myself?', 'document': '92cd22cada'}
# {'question': 'When is dot product the same as cosine similarity in vector search?', 'document': '92cd22cada'}
# {'question': 'Why doesn’t dot product work as cosine similarity for TF-IDF + SVD embeddings?', 'document': '92cd22cada'}
# {'question': 'In the homework, what changes if I skip vector normalization before comparing documents?', 'document': '92cd22cada'}
# {'question': 'For vector search, do I index the question, the answer, or both together?', 'document': '5c4a8d2e60'}
# {'question': 'Is it better to embed just the answer text or the question text when building the vector index?', 'document': '5c4a8d2e60'}
# {'question': 'Why would combining the question and answer into one embedding help, and is it worth the extra cost?', 'document': '5c4a8d2e60'}
# {'question': 'How do I decide which embedding setup gives the best retrieval results on my data?', 'document': '5c4a8d2e60'}
# {'question': 'Does the course recommend one embedding strategy for vector search, or is it something I need to test myself?', 'document': '5c4a8d2e60'}
# {'question': 'How does cosine similarity measure how close two vectors are in text search?', 'document': 'db78580409'}
# {'question': 'Why is cosine similarity used for comparing documents instead of just their raw word counts?', 'document': 'db78580409'}
# {'question': 'What does it mean if cosine similarity is 1, 0, or -1 between two vectors?', 'document': 'db78580409'}
# {'question': 'Can cosine similarity be used with TF-IDF vectors, and why does that help in document comparison?', 'document': 'db78580409'}
# {'question': 'What kind of vectors can cosine similarity compare, and what does the angle between them tell us?', 'document': 'db78580409'}
# {'question': 'Why can cosine similarity be computed with a matrix multiply once the embeddings are normalized?', 'document': '95feb4e75b'}
# {'question': 'What changes when the vectors are unit length, and why does that make cosine similarity easier to calculate?', 'document': '95feb4e75b'}
# {'question': 'How does normalizing the document embeddings and query help turn cosine similarity into a dot product?', 'document': '95feb4e75b'}
# {'question': 'Why do we say cosine similarity ignores vector size, and how does that connect to matrix multiplication?', 'document': '95feb4e75b'}
# {'question': 'In vector search, why is it enough to compare normalized embeddings with the query using dot products?', 'document': '95feb4e75b'}
# {'question': 'Why am I getting `JSONDecodeError: Expecting value` when I try to parse the LLM output with `json.loads`?', 'document': 'a3c7e1b4f9'}
# {'question': 'How can I make the model return only valid JSON instead of wrapping it in a code block or extra text?', 'document': 'a3c7e1b4f9'}
# {'question': 'What should I add to my prompt so the LLM outputs a JSON object with a `questions` list and nothing else?', 'document': 'a3c7e1b4f9'}
# {'question': 'Can I force structured JSON output with OpenAI when generating ground-truth questions for evaluation?', 'document': 'a3c7e1b4f9'}
# {'question': 'Do other LLM APIs like Gemini or Groq have a way to return JSON directly?', 'document': 'a3c7e1b4f9'}
# {'question': 'Why does my Jupyter kernel die when I try to embed the ground-truth data in Module 4?', 'document': 'b8f2d6a30c'}
# {'question': 'What can I do on a low-RAM machine if the notebook crashes while loading the embedding model?', 'document': 'b8f2d6a30c'}
# {'question': 'Is there a smaller embedding model I can swap in to avoid memory issues, and will that affect my eval results?', 'document': 'b8f2d6a30c'}
# {'question': 'Would it help if I move the embedding part out of the notebook and run it as a separate script?', 'document': 'b8f2d6a30c'}
# {'question': 'How can I handle the ground-truth embeddings in batches so I don’t run out of memory?', 'document': 'b8f2d6a30c'}
# {'question': 'Why does adding `time.sleep(4)` still not prevent me from hitting Gemini limits while creating the ground-truth dataset?', 'document': 'c1e9f4b820'}
# {'question': 'What can I do if the free Gemini quota runs out in the middle of a long `tqdm` loop?', 'document': 'c1e9f4b820'}
# {'question': 'Is it worth switching to OpenAI `gpt-4o-mini` instead of Gemini for dataset generation, and why?', 'document': 'c1e9f4b820'}
# {'question': 'Can I use Groq’s free tier for this task, and which model should I pick?', 'document': 'c1e9f4b820'}
# {'question': 'How should I change my thread pool or save progress so I can continue after a rate-limit error?', 'document': 'c1e9f4b820'}
# {'question': 'How do I fix the WinError 126 message when torch tries to load fbgemm.dll on Windows?', 'document': '15e931476c'}
# {'question': 'If I get "The specified module could not be found" for fbgemm.dll in Python on Windows, what should I install?', 'document': '15e931476c'}
# {'question': 'Does this torch fbgemm.dll import error usually mean I need Visual C++ Redistributable or Visual Studio on Windows?', 'document': '15e931476c'}
# {'question': "I'm seeing a missing dependency error for fbgemm.dll in PyTorch on Windows 10/11 — what’s the workaround?", 'document': '15e931476c'}
# {'question': 'What can I do when Python says it can’t load torch\\lib\\fbgemm.dll because a module is missing?', 'document': '15e931476c'}
# {'question': 'Why am I getting a psycopg2 OperationalError that says it can’t translate host name "postgres" when I run prep.py?', 'document': '4b65d5542d'}
# {'question': 'How do I fix the "could not translate host name postgres to address" error in prep.py?', 'document': '4b65d5542d'}
# {'question': 'What should I change in my .env file if postgres host is not found when running the monitoring prep script?', 'document': '4b65d5542d'}
# {'question': 'Is there a reason I need to set POSTGRES_HOST to localhost instead of postgres for this error?', 'document': '4b65d5542d'}
# {'question': 'My python prep.py crashes with OperationalError about postgres host resolution — what’s the correct env setting to use?', 'document': '4b65d5542d'}
# {'question': 'How do I make Pandas show the full text in a column instead of cutting it off?', 'document': '641aedbbf5'}
# {'question': 'Is there a setting to stop Pandas from truncating long strings in DataFrame columns?', 'document': '641aedbbf5'}
# {'question': 'In the offline-rag-evaluation notebook, how can I see the whole Explanation text from the judge LLM?', 'document': '641aedbbf5'}
# {'question': 'Why does Pandas only display part of my column text, and how can I change that?', 'document': '641aedbbf5'}
# {'question': 'What option do I need to set so a column with long text shows everything, not just 50 characters?', 'document': '641aedbbf5'}
# {'question': 'How can I normalize a vector stored in a Pandas DataFrame column?', 'document': '5039707c1a'}
# {'question': 'What’s the easiest way to make every vector in a Pandas Series have length 1?', 'document': '5039707c1a'}
# {'question': 'Is there a simple Pandas apply example for normalizing vectors in one column?', 'document': '5039707c1a'}
# {'question': 'How do I divide each vector by its own norm inside a DataFrame column?', 'document': '5039707c1a'}
# {'question': 'Can I normalize a whole column of numpy vectors with a lambda function in Pandas?', 'document': '5039707c1a'}
# {'question': 'How do I get the 75th percentile for a column in a Pandas DataFrame?', 'document': 'b4c8ac5a0c'}
# {'question': 'What’s the Pandas way to calculate a 0.75 quantile on a Series?', 'document': 'b4c8ac5a0c'}
# {'question': 'How can I find a column’s percentile value in Pandas without using numpy?', 'document': 'b4c8ac5a0c'}
# {'question': 'Is there a simple method in Pandas to compute a quantile for one column?', 'document': 'b4c8ac5a0c'}
# {'question': 'How do I extract the 75% cutoff from a DataFrame column using Pandas?', 'document': 'b4c8ac5a0c'}
# {'question': 'How do I wipe out every Docker container from the terminal, even the ones still running?', 'document': '66ccbb7da0'}
# {'question': 'What’s the command to force-remove all Docker images at once?', 'document': '66ccbb7da0'}
# {'question': 'How can I delete every Docker volume using the command line?', 'document': '66ccbb7da0'}
# {'question': 'Is there a quick way to clean up all containers, images, and volumes in Docker without doing them one by one?', 'document': '66ccbb7da0'}
# {'question': 'What terminal commands should I run to fully clear Docker stuff like containers, images, and volumes?', 'document': '66ccbb7da0'}
# {'question': 'How can I make sure a user can only send feedback once per submission in Streamlit, like just +1 or -1?', 'document': '2e729f1271'}
# {'question': 'Why does `st.session.submitted` keep getting set back to `True` even after I click one of the feedback buttons?', 'document': '2e729f1271'}
# {'question': 'After I press the ask button, what’s the right way to disable the buttons until the submission state changes?', 'document': '2e729f1271'}
# {'question': 'Is there a known Streamlit session-state issue where a session flag gets reassigned unexpectedly after a button click?', 'document': '2e729f1271'}
# {'question': 'Where can I find the fix for the problem where `st.session.submitted` changes again after feedback is given?', 'document': '2e729f1271'}
# {'question': 'Why does my streamlit app fail in docker-compose with "streamlit: executable file not found in $PATH", even though it works locally?', 'document': 'e8df9f0d12'}
# {'question': 'Do I need a Dockerfile when running a streamlit app with docker-compose, or is compose config enough?', 'document': 'e8df9f0d12'}
# {'question': "How do I fix the OCI runtime error when docker-compose says it can't find the streamlit command?", 'document': 'e8df9f0d12'}
# {'question': 'What should I change in docker-compose so my streamlit container starts correctly?', 'document': 'e8df9f0d12'}
# {'question': 'After adding streamlit to docker-compose, do I need to rebuild the image or just restart the containers?', 'document': 'e8df9f0d12'}
# {'question': 'Is the capstone project something we do alone, or can it be a group project?', 'document': '0fab61eca2'}
# {'question': 'Do students work in teams for the capstone, or is it individual only?', 'document': '0fab61eca2'}
# {'question': 'Can I team up with someone for the capstone, or do I have to do it solo?', 'document': '0fab61eca2'}
# {'question': 'Is the final capstone meant to be completed by one person or by a group?', 'document': '0fab61eca2'}
# {'question': 'For the capstone, do we need partners or is it a solo assignment?', 'document': '0fab61eca2'}
# {'question': 'Do I have to submit two separate capstone projects, or is one project enough for the course?', 'document': 'd5fc98925d'}
# {'question': 'What exactly do attempt 1 and attempt 2 mean for the capstone submission timeline?', 'document': 'd5fc98925d'}
# {'question': 'If my first capstone submission doesn’t pass, can I fix it and send it again later?', 'document': 'd5fc98925d'}
# {'question': 'Can I submit two projects just to get more practice, and if so do they need to be on different topics?', 'document': 'd5fc98925d'}
# {'question': 'If I miss the first submission window, do I still have a chance to submit in the second one and stay eligible?', 'document': 'd5fc98925d'}
# {'question': 'Is the competition itself accepted as the capstone project, or is the capstone supposed to be something else?', 'document': 'e892d44e42'}
# {'question': 'Can I join the math-kaggle LLM competition with a team and still use that for my capstone?', 'document': 'e892d44e42'}
# {'question': 'If I want to form a group for the competition, does that replace the individual capstone requirement?', 'document': 'e892d44e42'}
# {'question': 'Does taking part in the competition count toward the capstone, or do I still need to do an individual project?', 'document': 'e892d44e42'}
# {'question': "Can the capstone be done as a team if I'm already participating in the competition?", 'document': 'e892d44e42'}
# {'question': 'How will my capstone project be graded?', 'document': '9a2e2d2008'}
# {'question': 'Who actually reviews the capstone submissions?', 'document': '9a2e2d2008'}
# {'question': "Do I need to evaluate other students' projects too?", 'document': '9a2e2d2008'}
# {'question': 'What happens if I skip the peer-review part?', 'document': '9a2e2d2008'}
# {'question': 'How is the final score for the capstone calculated?', 'document': '9a2e2d2008'}
# {'question': 'When do we get the projects to review and grade, and how are they assigned?', 'document': 'eae0fb50aa'}
# {'question': 'Will project review assignments come before or after the submission deadline?', 'document': 'eae0fb50aa'}
# {'question': 'How many projects does each participant have to grade in the capstone project?', 'document': 'eae0fb50aa'}
# {'question': 'What happens once the submission deadline is over for project grading?', 'document': 'eae0fb50aa'}
# {'question': 'Do we get an Excel sheet with the review assignments, and what will it include?', 'document': 'eae0fb50aa'}
# {'question': 'I already turned in my capstone project, so why am I not seeing anything to review yet?', 'document': 'a8a7fef016'}
# {'question': 'When do the projects for evaluation get assigned after the submission deadline ends?', 'document': 'a8a7fef016'}
# {'question': 'Can I pick which capstone projects I want to review, or is that decided for me?', 'document': 'a8a7fef016'}
# {'question': 'Is there any way to start reviewing submissions before the project list is released?', 'document': 'a8a7fef016'}
# {'question': "I submitted my project already, but I still can't review others — is that normal?", 'document': 'a8a7fef016'}
# {'question': 'Where can I look for project ideas and datasets for the capstone project?', 'document': 'e76a70cde3'}
# {'question': 'Is there a place with a few dataset options and example ideas for the LLM Zoomcamp project?', 'document': 'e76a70cde3'}
# {'question': 'What’s the best link to check for capstone project inspiration and data sources?', 'document': 'e76a70cde3'}
# {'question': 'Can you point me to a GitHub page that lists project ideas, datasets, and some guidance?', 'document': 'e76a70cde3'}
# {'question': 'I’m stuck on picking a project — where can I find suggestions and usable datasets?', 'document': 'e76a70cde3'}
# {'question': 'Do I have to use Airflow, Mage, or Kestra for the capstone project, or is a simple Python script enough?', 'document': 'd4f7c08ea1'}
# {'question': 'If I build the ingestion and indexing steps in a Jupyter notebook, will that count for the full pipeline points?', 'document': 'd4f7c08ea1'}
# {'question': 'When does it actually make sense to add an orchestrator to a capstone project instead of just using Python?', 'document': 'd4f7c08ea1'}
# {'question': 'Can I still get the ingestion pipeline criterion without setting up a workflow tool at all?', 'document': 'd4f7c08ea1'}
# {'question': 'Should I avoid adding an orchestration tool just for grading, and only use one if my data gets updated regularly?', 'document': 'd4f7c08ea1'}
# {'question': "How can I evaluate a recommender-style RAG project if I don't have clear ground-truth answers?", 'document': '9b0e2d6a47'}
# {'question': 'Is there a good way to create test queries for items in my dataset so I can measure retrieval quality?', 'document': '9b0e2d6a47'}
# {'question': 'What metrics should I use for a ranking-style RAG system: hit rate, MRR, or NDCG?', 'document': '9b0e2d6a47'}
# {'question': 'How do I use an LLM as a judge to score the output of my RAG pipeline end to end?', 'document': '9b0e2d6a47'}
# {'question': 'For recommenders where several items could be acceptable, why would NDCG be better than just checking whether the top result is correct?', 'document': '9b0e2d6a47'}
# {'question': 'How should I chunk a big PDF corpus without overthinking it at first?', 'document': '6f2a8b3d10'}
# {'question': 'Is it better to use fixed-size chunks or ask an LLM to split docs into sections?', 'document': '6f2a8b3d10'}
# {'question': 'Should I add summaries to each chunk before indexing, and does that actually help retrieval?', 'document': '6f2a8b3d10'}
# {'question': 'For long legal or financial docs, is BM25 plus dense search better than only embeddings?', 'document': '6f2a8b3d10'}
# {'question': 'What are good tools to turn PDFs into cleaner markdown before I chunk them?', 'document': '6f2a8b3d10'}
# {'question': 'What does reproducibility mean for the project review?', 'document': 'e5d8a2c761'}
# {'question': 'Do I need to put my API keys or service credentials in the repo so the reviewer can run it?', 'document': 'e5d8a2c761'}
# {'question': 'How should I let someone rebuild the search index from the dataset on their own machine?', 'document': 'e5d8a2c761'}
# {'question': 'What should go into a .env.example file, and should .env be committed?', 'document': 'e5d8a2c761'}
# {'question': 'How do I make the project easier and cheaper for reviewers to run, like with model choice and pinned versions?', 'document': 'e5d8a2c761'}
# {'question': 'Can I reuse the workshop content in my own capstone project, or is it only for the class?', 'document': 'd850a0e7ea'}
# {'question': 'Since dlt is open-source, am I allowed to use these materials in another project outside the workshop?', 'document': 'd850a0e7ea'}
# {'question': 'Could I apply what we learned here to a different Zoomcamp project, like the MLOps one?', 'document': 'd850a0e7ea'}
# {'question': 'Is it okay if I share the workshop resources with other people, or are they meant just for students?', 'document': 'd850a0e7ea'}
# {'question': 'If I want to use dlt directly in my own project, do I need any special permission, or can I just go ahead and do it?', 'document': 'd850a0e7ea'}
# {'question': 'How do I start a new dlt project for loading data from cloud storage?', 'document': '6bceeebf04'}
# {'question': "What's the command to initialize a dlt pipeline with filesystem and DuckDB?", 'document': '6bceeebf04'}
# {'question': 'If I want to ingest cloud files into DuckDB with dlt, what should I run first?', 'document': '6bceeebf04'}
# {'question': 'How can I create a fresh dlt setup for a filesystem source?', 'document': '6bceeebf04'}
# {'question': 'Is there a quick init command for a dlt project using filesystem plus DuckDB?', 'document': '6bceeebf04'}
# {'question': 'Why do I get `Table notion_pages___homework does not exist` when I call `db.open_table("notion_pages___homework")`?', 'document': '0407213397'}
# {'question': 'I changed the table name in one place, but now opening `notion_pages___homework` still fails. What am I missing?', 'document': '0407213397'}
# {'question': 'What could cause `db.open_table("notion_pages___homework")` to say the table doesn\'t exist even though my pipeline ran?', 'document': '0407213397'}
# {'question': 'Is there another setting besides the table name I need to update when switching from `employee_handbook` to `homework`?', 'document': '0407213397'}
# {'question': 'How do I fix the `FileNotFoundError` for `notion_pages___homework` in the dlt workshop?', 'document': '0407213397'}
# {'question': 'Why am I getting FileNotFoundError: Table notion_pages___homework does not exist when I run main() in the dlt workshop?', 'document': 'e95bfafc0e'}
# {'question': 'How do I fix the error saying I should first call db.create_table(notion_pages___homework, data) in the Notion pages homework code?', 'document': 'e95bfafc0e'}
# {'question': "What table name should I open in line 3 if my script says notion_pages___homework doesn't exist?", 'document': 'e95bfafc0e'}
# {'question': 'Is db.open_table supposed to use notion_pages___homework in this exercise, and where exactly should I change it?', 'document': 'e95bfafc0e'}
# {'question': 'I keep seeing Table notion_pages___homework does not exist — what’s the correct table to open in main()?', 'document': 'e95bfafc0e'}
# {'question': 'How can I list all tables that are currently in the database?', 'document': 'e394e6f738'}
# {'question': 'Is there a way to see the table names from the db object?', 'document': 'e394e6f738'}
# {'question': 'What method should I use to check which tables exist in my database?', 'document': 'e394e6f738'}
# {'question': 'How do I find out what tables were created in the db?', 'document': 'e394e6f738'}
# {'question': 'Can I get a list of all tables with db.table_names()?', 'document': 'e394e6f738'}
# {'question': 'Does dlt currently support connectors for ClickHouse or StarRocks, or is that still missing?', 'document': 'cd19f122f3'}
# {'question': 'Can I use dlt to load data into ClickHouse or StarRocks right now?', 'document': 'cd19f122f3'}
# {'question': 'Are there official dlt connectors available for ClickHouse and StarRocks?', 'document': 'cd19f122f3'}
# {'question': "If dlt doesn't support ClickHouse or StarRocks yet, is the project open to community-built connectors?", 'document': 'cd19f122f3'}
# {'question': 'Has anyone added ClickHouse or StarRocks connectors to dlt, or are those still not included?', 'document': 'cd19f122f3'}
# {'question': 'Why am I getting a 401 Unauthorized from the Notion API in the notebook, and what should I check first?', 'document': '0dfba07ace'}
# {'question': 'My notebook says it has no secret access to api.notion.com/v1/search — is this an API key problem?', 'document': '0dfba07ace'}
# {'question': 'How do I fix a Notion API authorization error in the dlt workshop notebook?', 'document': '0dfba07ace'}
# {'question': 'Could the Notion token have expired if I get Unauthorized when calling the search endpoint?', 'document': '0dfba07ace'}
# {'question': 'What settings or permissions do I need to verify when the notebook can’t access Notion and returns 401?', 'document': '0dfba07ace'}
# {'question': "Why do I get a 401 Client Error when using the API key, and how do I tell if it's just not granted access yet?", 'document': '4b30b918bc'}
# {'question': "What's the easiest way to force-install requests 2.32.3 instead of the older 2.28 version for lancedb?", 'document': '4b30b918bc'}
# {'question': 'Can I install requests straight from the GitHub release zip to match the version lancedb needs?', 'document': '4b30b918bc'}
# {'question': 'If pip keeps pulling requests v2.28, what exact install command should I run to get v2.32.3?', 'document': '4b30b918bc'}
# {'question': 'How do I fix the requests version mismatch when setting up the dlt workshop environment?', 'document': '4b30b918bc'}

# %%
#q=ground_truth[10]

# %%
doc_idx = {}
for doc in documents:
    doc_idx[doc["doc_id"]]=doc

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os
load_dotenv()


#openai_client = OpenAI()    

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
        timeout=15.0,
    max_retries=1,
)

# %%
from evaluation_utils import RAGWithUsage

assistant = RAGWithUsage(
    index=index,
    llm_client=openai_client,
    course='llm-zoomcamp',
    )

# %%
q['question']
# Out:
# 'How do I fix the requests version mismatch when setting up the dlt workshop environment?'

# %%
answer = assistant.rag(q['question'])
print(answer)
# Out:
# Based on the provided context, the question is:
#
# "How do I fix the requests version mismatch when setting up the dlt workshop environment?"
#
# According to the context, you can fix the requests version mismatch by using the following command:
#
# ```
# pip install "requests @ https://github.com/psf/requests/archive/refs/tags/v2.32.3.zip"
# ```
#
# This command installs the requests library directly from the source, specifically the version 2.32.3, which is the required version for lancedb.

# %%
doc_idx[q['document']]
# Out:
# {'course': 'llm-zoomcamp',
#  'section': 'Workshop: Open-Source Data Ingestion (dlt)',
#  'question': 'Error: How to fix requests library only installs v2.28 instead of v2.32 required for lancedb?',
#  'answer': 'If you encounter a 401 Client Error, it may indicate the need to grant access to the key or that the key is incorrect.\n\nTo install the correct version directly from the source, use the following command:\n\n```bash\npip install "requests @ https://github.com/psf/requests/archive/refs/tags/v2.32.3.zip"\n```',
#  'doc_id': '4b30b918bc'}

# %%
### Runing RAG for one question

rec = ground_truth[0]
question = rec["question"]

answer_llm = assistant.rag(question)
print(answer_llm)
# Out:
# According to the course-related information, it is okay to join the course late if you just found it now. The course does not have any specific time restrictions for joining, and you can still submit your project to receive a certificate while submissions are still accepted.

# %%
assistant.total_cost()
# Out:
# 0.00148875

# %%
doc_id = rec["document"]
original_doc = doc_idx[doc_id]
answer_orig = original_doc["answer"]

print(answer_orig)
# Out:
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.

# %%
rag_result = {
    "question": question,
    "answer_llm": answer_llm,
    "answer_orig": answer_orig,
    "document": doc_id,
}

print(rag_result)
# Out:
# {'question': 'Is it okay to join the course late if I just found it now?', 'answer_llm': 'According to the course-related information, it is okay to join the course late if you just found it now. The course does not have any specific time restrictions for joining, and you can still submit your project to receive a certificate while submissions are still accepted.', 'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.', 'document': '74eb249bbf'}

# %% [markdown]
# ### Processing all questions

# %%
def generate_rag_answer(rec):
    question = rec["question"]
    doc_id = rec["document"]
    original_doc = doc_idx[doc_id]

    answer_llm = assistant.rag(question)
    answer_orig = original_doc["answer"]

    result = {
        "question": question,
        "answer_llm": answer_llm,
        "answer_orig": answer_orig,
        "document": doc_id,
    }

    return result

# %%
answer_record = generate_rag_answer(ground_truth[0])
answer_record
# Out:
# {'question': 'Is it okay to join the course late if I just found it now?',
#  'answer_llm': 'Based on the context, to your question: "Yes, it is okay to join the course late if I just found it now." If you want to receive a certificate, you\'ll need to submit your project while the course is still accepting submissions.',
#  'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#  'document': '74eb249bbf'}

# %%
assistant.total_cost()
# Out:
# 0.0020805

# %%
assistant.reset_usage()

# %%
assistant.total_cost()
# Out:
# 0.0

# %%
from concurrent.futures import ThreadPoolExecutor
from evaluation_utils import map_progress

# %%
with ThreadPoolExecutor(max_workers=1) as pool:
    results = map_progress(pool, ground_truth[:6], generate_rag_answer)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
answers = []

for answer_record in results:
    answers.append(answer_record)

# %%
assistant.total_cost()
# Out:
# 0.00504375

# %%
df_answers = pd.DataFrame(answers)
df_answers.to_csv("data/rag-answers-new-v2.csv", index=False)
