# %%
import sys
sys.path.insert(0, '/app/04-evaluation/code')

from ingest import load_faq_data
documents = load_faq_data()


documents_llm = [] 

for doc in documents:
    if doc["course"] == "llm-zoomcamp":
        documents_llm.append(doc)

len(documents_llm)



documents = documents_llm


doc
# Out:
# {'course': 'machine-learning-zoomcamp',
#  'section': 'Miscellaneous',
#  'question': "My homework answer doesn't match any of the options",
#  'answer': "Common causes, in order of frequency:\n\n1. Wrong column slice or filter — apply filters BEFORE selecting columns / `.head(n)` / `.values`.\n2. Log transform applied where it shouldn't be (or not applied where it should).\n3. Rounding too early — only round the final answer, not intermediate values, unless explicitly told to.\n4. Different sklearn / numpy / Python versions — pin them via `requirements.txt`, `Pipfile.lock`, or `uv.lock`.\n5. Different train/val/test split logic — `train_test_split` shuffles by default; manual `np.random.shuffle` produces a different ordering than sklearn's.\n\nIf after these checks your answer still doesn't match, pick the closest option — the homework explicitly allows it.",
#  'doc_id': 'ab183bd688'}

# %%
doc = documents[0]
print(doc["doc_id"])
print(doc["question"])
print(doc["answer"])


from pydantic import BaseModel

class Questions(BaseModel):
    questions: list[str]
# Out:
# 74eb249bbf
# I just discovered the course. Can I still join?
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.

# %%
import os
print(os.path.exists('/app/04-evaluation/code/ingest.py'))
print(os.listdir('/app/04-evaluation'))
# Out:
# True
# ['.ipynb_checkpoints', '01-data-gen.ipynb', 'code']

# %%
data_gen_instructions = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record.

The output should resemble how people ask questions
on the internet. Not too formal, not too short, not too long.
""".strip()

# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()


#openai_client = OpenAI()    

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
import json

user_prompt = json.dumps(doc)
user_prompt
# Out:
# '{"course": "llm-zoomcamp", "section": "General Course-Related Questions", "question": "I just discovered the course. Can I still join?", "answer": "Yes, but if you want to receive a certificate, you need to submit your project while we\\u2019re still accepting submissions.", "doc_id": "74eb249bbf"}'

# %%
messages = [
    {"role": "developer", "content": data_gen_instructions},
    {"role": "user", "content": user_prompt}
]

# %%
response = openai_client.responses.parse(
        model="openai/gpt-oss-20b",
        input=messages,
        text_format=Questions

)

# %%
response.output_parsed
result = response.output_parsed

print(result)
# Out:
# questions=['How can I enroll after the start of the course?', 'Can I still register for the course and get a certificate?', 'What do I need to do if I joined late to qualify for the certificate?', 'Is it possible to join the course now and still submit my project?', 'Do I need to submit a project to get a certificate if I’m joining late?']

# %%
print(result.questions[2])
# Out:
# What do I need to do if I joined late to qualify for the certificate?

# %%
for i in (result.questions):
    print(i)
# Out:
# How can I enroll after the start of the course?
# Can I still register for the course and get a certificate?
# What do I need to do if I joined late to qualify for the certificate?
# Is it possible to join the course now and still submit my project?
# Do I need to submit a project to get a certificate if I’m joining late?

# %%
len(documents)
# Out:
# 115

# %%
sys.path.insert(0, '/app/04-evaluation/code')

from evaluation_utils import llm_structured

# %%
result, usage = llm_structured(
    openai_client,
    data_gen_instructions,
    user_prompt,
    Questions
)

print(result.questions)
# Out:
# ['Can I still enroll and get a certificate if I start late?', 'Do I need to turn in a project to qualify for the certificate?', 'What happens if I miss the project submission deadline?', 'Is it possible to join the course and still earn a certificate?', 'Do I have to submit a project before the course ends?']

# %%
from evaluation_utils import calc_price

# %%
cost = calc_price(usage)

cost
# Out:
# {'input_cost': 0.000252,
#  'output_cost': 0.0019034999999999998,
#  'total_cost': 0.0021555}

# %%
records = []

for q in result.questions:
    records.append({
        "question": q,
        "document": doc["doc_id"]
    })

records
# Out:
# [{'question': 'Can I still enroll and get a certificate if I start late?',
#   'document': '74eb249bbf'},
#  {'question': 'Do I need to turn in a project to qualify for the certificate?',
#   'document': '74eb249bbf'},
#  {'question': 'What happens if I miss the project submission deadline?',
#   'document': '74eb249bbf'},
#  {'question': 'Is it possible to join the course and still earn a certificate?',
#   'document': '74eb249bbf'},
#  {'question': 'Do I have to submit a project before the course ends?',
#   'document': '74eb249bbf'}]

# %% [markdown]
# ## 4.3 -- Ground Truth for All Documents

# %%
from evaluation_utils import llm_structured_retry

# %%
def generate_ground_truth(doc):
    user_prompt = json.dumps(doc)

    out, usage = llm_structured_retry(
        openai_client,
        data_gen_instructions,
        user_prompt,
        Questions
    )

    results = []

    for q in out.questions:
        results.append({
            "question": q,
            "document": doc["doc_id"]
        })

    return results, usage

# %%
from tqdm.auto import tqdm

ground_truth = []
usages = []

for doc in tqdm(documents[:5]):
    records, usage = generate_ground_truth(doc)
    ground_truth.extend(records)
    usages.append(usage)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[44], line 7
#       3 ground_truth = []
#       4 usages = []
#       5
#       6 for doc in tqdm(documents[:5]):
# ----> 7     records, usage = generate_ground_truth(doc)
#       8     ground_truth.extend(records)
#       9     usages.append(usage)
#
# Cell In[43], line 4, in generate_ground_truth(doc)
#       1 def generate_ground_truth(doc):
#       2     user_prompt = json.dumps(doc)
#       3
# ----> 4     out, usage = llm_structured_retry(
#       5         openai_client,
#       6         data_gen_instructions,
#       7         user_prompt,
#
# File /app/04-evaluation/code/evaluation_utils.py:58, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#      56 for attempt in range(max_retries):
#      57     try:
# ---> 58         return llm_structured(
#      59             client,
#      60             instructions,
#      61             user_prompt,
#      62             output_type,
#      63             model=model,
#      64         )
#      65     except Exception:
#      66         if attempt == max_retries - 1:
#
# File /app/04-evaluation/code/evaluation_utils.py:38, in llm_structured(client, instructions, user_prompt, output_type, model)
#      32 def llm_structured(client, instructions, user_prompt, output_type, model="openai/gpt-oss-20b"):
#      33     messages = [
#      34         {"role": "system", "content": instructions},
#      35         {"role": "user", "content": user_prompt}
#      36     ]
# ---> 38     response = client.beta.chat.completions.parse(
#      39         model=model,
#      40         messages=messages,
#      41         response_format=output_type
#      42     )
#      44     return response.choices[0].message.parsed, response.usage
#
# File /usr/local/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:193, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     186 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     187     return _parse_chat_completion(
#     188         response_format=response_format,
#     189         chat_completion=raw_completion,
#     190         input_tools=chat_completion_tools,
#     191     )
# --> 193 return self._post(
#     194     "/chat/completions",
#     195     body=maybe_transform(
#     196         {
#     197             "messages": messages,
#     198             "model": model,
#     199             "audio": audio,
#     200             "frequency_penalty": frequency_penalty,
#     201             "function_call": function_call,
#     202             "functions": functions,
#     203             "logit_bias": logit_bias,
#     204             "logprobs": logprobs,
#     205             "max_completion_tokens": max_completion_tokens,
#     206             "max_tokens": max_tokens,
#     207             "metadata": metadata,
#     208             "modalities": modalities,
#     209             "moderation": moderation,
#     210             "n": n,
#     211             "parallel_tool_calls": parallel_tool_calls,
#     212             "prediction": prediction,
#     213             "presence_penalty": presence_penalty,
#     214             "prompt_cache_key": prompt_cache_key,
#     215             "prompt_cache_options": prompt_cache_options,
#     216             "prompt_cache_retention": prompt_cache_retention,
#     217             "reasoning_effort": reasoning_effort,
#     218             "response_format": _type_to_response_format(response_format),
#     219             "safety_identifier": safety_identifier,
#     220             "seed": seed,
#     221             "service_tier": service_tier,
#     222             "stop": stop,
#     223             "store": store,
#     224             "stream": False,
#     225             "stream_options": stream_options,
#     226             "temperature": temperature,
#     227             "tool_choice": tool_choice,
#     228             "tools": tools,
#     229             "top_logprobs": top_logprobs,
#     230             "top_p": top_p,
#     231             "user": user,
#     232             "verbosity": verbosity,
#     233             "web_search_options": web_search_options,
#     234         },
#     235         completion_create_params.CompletionCreateParams,
#     236     ),
#     237     options=make_request_options(
#     238         extra_headers=extra_headers,
#     239         extra_query=extra_query,
#     240         extra_body=extra_body,
#     241         timeout=timeout,
#     242         post_parser=parser,
#     243         security={"bearer_auth": True},
#     244     ),
#     245     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     246     # in the `parser` function above
#     247     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     248     stream=False,
#     249 )
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-20b` in organization `org_01kt5mkx5qe4t9vapq9stxqm8s` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7833, Requested 1345. Please try again in 8.835s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ## Parallel Processing

# %%
from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
    # no base_url — uses OpenAI directly
)

# %%
from openai import OpenAI
import os

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# reload after the file change
import importlib, evaluation_utils

importlib.reload(evaluation_utils)
from evaluation_utils import llm_structured_retry_openai

result, usage = llm_structured_retry_openai(
    openai_client,
    data_gen_instructions,
    user_prompt,
    Questions
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 importlib.reload(evaluation_utils)
#       2 from evaluation_utils import llm_structured_retry_openai
#       3
#       4 result, usage = llm_structured_retry_openai(
#
# NameError: name 'importlib' is not defined

# %%
result, usage = llm_structured(
    openai_client,
    data_gen_instructions,
    user_prompt,
    Questions,
    model="gpt-4o-mini"   # ← change this
)

# %%
from concurrent.futures import ThreadPoolExecutor
from evaluation_utils import map_progress

# %%
with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, documents, generate_ground_truth)
# Out:
#   0%|          | 0/1377 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 with ThreadPoolExecutor(max_workers=6) as pool:
#       2     results = map_progress(pool, documents, generate_ground_truth)
#
# File /app/04-evaluation/code/evaluation_utils.py:125, in map_progress(pool, seq, f)
#     124 for future in futures:
# --> 125     result = future.result()
#     126     results.append(result)
#
# File /usr/local/lib/python3.13/concurrent/futures/_base.py:460, in Future.result(self, timeout)
#     459 elif self._state == FINISHED:
# --> 460     return self.__get_result()
#     461 else:
#
# File /usr/local/lib/python3.13/concurrent/futures/_base.py:402, in Future.__get_result(self)
#     401 try:
# --> 402     raise self._exception
#     403 finally:
#     404     # Break a reference cycle with the exception in self._exception
#
# File /usr/local/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# Cell In[19], line 4, in generate_ground_truth(doc)
#       2     user_prompt = json.dumps(doc)
#       3
# ----> 4     out, usage = llm_structured_retry(
#       5         openai_client,
#
# File /app/04-evaluation/code/evaluation_utils.py:58, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#      57 try:
# ---> 58     return llm_structured(
#      59         client,
#      60         instructions,
#      61         user_prompt,
#      62         output_type,
#      63         model=model,
#      64     )
#      65 except Exception:
#
# File /app/04-evaluation/code/evaluation_utils.py:38, in llm_structured(client, instructions, user_prompt, output_type, model)
#      33 messages = [
#      34     {"role": "system", "content": instructions},
#      35     {"role": "user", "content": user_prompt}
#      36 ]
# ---> 38 response = client.beta.chat.completions.parse(
#      39     model=model,
#      40     messages=messages,
#      41     response_format=output_type
#      42 )
#      44 return response.choices[0].message.parsed, response.usage
#
# File /usr/local/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:193, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     187     return _parse_chat_completion(
#     188         response_format=response_format,
#     189         chat_completion=raw_completion,
#     190         input_tools=chat_completion_tools,
#     191     )
# --> 193 return self._post(
#     194     "/chat/completions",
#     195     body=maybe_transform(
#     196         {
#     197             "messages": messages,
#     198             "model": model,
#     199             "audio": audio,
#     200             "frequency_penalty": frequency_penalty,
#     201             "function_call": function_call,
#     202             "functions": functions,
#     203             "logit_bias": logit_bias,
#     204             "logprobs": logprobs,
#     205             "max_completion_tokens": max_completion_tokens,
#     206             "max_tokens": max_tokens,
#     207             "metadata": metadata,
#     208             "modalities": modalities,
#     209             "moderation": moderation,
#     210             "n": n,
#     211             "parallel_tool_calls": parallel_tool_calls,
#     212             "prediction": prediction,
#     213             "presence_penalty": presence_penalty,
#     214             "prompt_cache_key": prompt_cache_key,
#     215             "prompt_cache_options": prompt_cache_options,
#     216             "prompt_cache_retention": prompt_cache_retention,
#     217             "reasoning_effort": reasoning_effort,
#     218             "response_format": _type_to_response_format(response_format),
#     219             "safety_identifier": safety_identifier,
#     220             "seed": seed,
#     221             "service_tier": service_tier,
#     222             "stop": stop,
#     223             "store": store,
#     224             "stream": False,
#     225             "stream_options": stream_options,
#     226             "temperature": temperature,
#     227             "tool_choice": tool_choice,
#     228             "tools": tools,
#     229             "top_logprobs": top_logprobs,
#     230             "top_p": top_p,
#     231             "user": user,
#     232             "verbosity": verbosity,
#     233             "web_search_options": web_search_options,
#     234         },
#     235         completion_create_params.CompletionCreateParams,
#     236     ),
#     237     options=make_request_options(
#     238         extra_headers=extra_headers,
#     239         extra_query=extra_query,
#     240         extra_body=extra_body,
#     241         timeout=timeout,
#     242         post_parser=parser,
#     243         security={"bearer_auth": True},
#     244     ),
#     245     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     246     # in the `parser` function above
#     247     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     248     stream=False,
#     249 )
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/lib/python3.13/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1104     log.debug("Re-raising status error")
# -> 1105     raise self._make_status_error_from_response(err.response) from None
#    1107 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `openai/gpt-oss-20b` in organization `org_01kt5mkx5qe4t9vapq9stxqm8s` service tier `on_demand` on tokens per minute (TPM): Limit 8000, Used 7963, Requested 966. Please try again in 6.9675s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 with ThreadPoolExecutor(max_workers=6) as pool:
#       2     results = map_progress(pool, documents, generate_ground_truth)
#
# File /usr/local/lib/python3.13/concurrent/futures/_base.py:653, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     652 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 653     self.shutdown(wait=True)
#     654     return False
#
# File /usr/local/lib/python3.13/concurrent/futures/thread.py:239, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 if wait:
#     238     for t in self._threads:
# --> 239         t.join()
#
# File /usr/local/lib/python3.13/threading.py:1095, in Thread.join(self, timeout)
#    1092 if timeout is not None:
#    1093     timeout = max(timeout, 0)
# -> 1095 self._handle.join(timeout)
#
# KeyboardInterrupt:

# %%
ground_truth = []
usages = []

for records, usage in results:
    ground_truth.extend(records)
    usages.append(usage)

len(ground_truth)
